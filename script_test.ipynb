# %%
from bs4 import BeautifulSoup
import requests

# %%
# URL = "https://www.comnetwork.org/newsletter-archive/"
URL = "https://hebrew-academy.org.il/topic/milim/%d7%9e%d7%98%d7%91%d7%a2%d7%95%d7%aa-%d7%9c%d7%a9%d7%95%d7%9f/"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")
for a_href in soup.find_all("a", href=True):
    print(a_href["href"])
# Out:
# #menu-header
# https://hebrew-academy.org.il
# https://hebrew-academy.org.il/
# https://hebrew-academy.org.il/topic/al_haakademya/
# https://hebrew-academy.org.il/2018/04/16/28646/
# https://hebrew-academy.org.il/topic/al_haakademya/vaadot/
# https://hebrew-academy.org.il/2018/10/02/%d7%97%d7%95%d7%a7-%d7%94%d7%9e%d7%95%d7%a1%d7%93-%d7%94%d7%a2%d7%9c%d7%99%d7%95%d7%9f-%d7%9c%d7%9c%d7%a9%d7%95%d7%9f-%d7%94%d7%a2%d7%91%d7%a8%d7%99%d7%aa/
# https://hebrew-academy.org.il/2018/10/02/%d7%aa%d7%a7%d7%a0%d7%95%d7%9f-%d7%94%d7%90%d7%a7%d7%93%d7%9e%d7%99%d7%94/
# https://hebrew-academy.org.il/topic/al_haakademya/%d7%91%d7%99%d7%aa-%d7%94%d7%90%d7%a7%d7%93%d7%9e%d7%99%d7%94-%d7%9c%d7%9c%d7%a9%d7%95%d7%9f-%d7%94%d7%a2%d7%91%d7%a8%d7%99%d7%aa/
# https://hebrew-academy.org.il/topic/al_haakademya/zikhronot/
# https://hebrew-academy.org.il/%d7%94%d7%9e%d7%a0%d7%95%d7%95%d7%94/
# ...
